# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[0]
recent_grads.head(2)
recent_grads.tail(2)
recent_grads.describe()
raw_data_count = recent_grads.shape[0]
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %%
cleaned_data_count
# Out:
# 172

# %%
recent_grads.plot('Sample_size','Median',kind = 'scatter')

# %%
recent_grads.plot('Sample_size','Unemployment_rate',kind = 'scatter')

# %%
recent_grads.plot('Full_time','Median',kind = 'scatter')

# %%
recent_grads.plot('ShareWomen','Unemployment_rate',kind = 'scatter')

# %%
recent_grads.plot('Men','Median',kind = 'scatter')

# %%
recent_grads.plot('Women','Median',kind = 'scatter')

# %%
recent_grads['Sample_size'].plot(kind = 'hist')

# %%
recent_grads['Sample_size'].hist(bins = 25,range = (0,5000))

# %%
recent_grads['Median'].plot(kind = 'hist')

# %%
recent_grads['Median'].hist(bins = 10,range = (20000,150000))

# %%
recent_grads['Employed'].plot(kind = 'hist')

# %%
cols = ['Sample_size','Median','Employed','Full_time','ShareWomen','Unemployment_rate','Men','Women']
fig = plt.figure(figsize = (5,12))

for i in range(1,9):
    ax = fig.add_subplot(8,1,i)
    ax = recent_grads[cols[i - 1]].plot(kind = 'hist')

# %%
from pandas.tools.plotting import scatter_matrix 
scatter_matrix(recent_grads[['Sample_size','Median']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f895625be10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8955cad9b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8955c76f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8955c36198>]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf3d82cb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf3d591438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf3d533128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf3d51b400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf3d46bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf3d425f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf3d373860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf3d336080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf3d2f8f98>]], dtype=object)

# %%
recent_grads[:10].plot.bar(x = 'Major',y = 'ShareWomen')
recent_grads[163:].plot.bar(x = 'Major',y = 'ShareWomen')
recent_grads[:10].plot.bar(x = 'Major',y = 'ShareWomen')
recent_grads[163:].plot.bar(x = 'Major',y = 'ShareWomen')
