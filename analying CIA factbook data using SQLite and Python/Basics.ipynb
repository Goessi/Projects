# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('factbook.db')
q = "SELECT * FROM sqlite_master WHERE type = 'table';"
pd.read_sql_query(q,conn)
# Out:
#     type             name         tbl_name  rootpage  \
# 0  table  sqlite_sequence  sqlite_sequence         3
# 1  table            facts            facts        47
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY...

# %%
q = "SELECT * FROM facts LIMIT 5"
pd.read_sql_query(q, conn)
# Out:
#    id code         name     area  area_land  area_water  population  \
# 0   1   af  Afghanistan   652230     652230           0    32564342
# 1   2   al      Albania    28748      27398        1350     3029278
# 2   3   ag      Algeria  2381741    2381741           0    39542166
# 3   4   an      Andorra      468        468           0       85580
# 4   5   ao       Angola  1246700    1246700           0    19625353
#
#    population_growth  birth_rate  death_rate  migration_rate
# 0               2.32       38.57       13.89            1.51
# 1               0.30       12.92        6.58            3.30
# 2               1.84       23.67        4.31            0.92
# 3               0.12        8.13        6.96            0.00
# 4               2.78       38.78       11.49            0.46

# %%
q1 = "SELECT MIN(population) FROM facts;"
q2 = "SELECT MAX(population) FROM facts;"
q3 = "SELECT MIN(population_growth) FROM facts;"
q4 = "SELECT MAX(population_growth) FROM facts;"
pd.read_sql_query(q1,conn)
# Out:
#    MIN(population)
# 0                0

# %%
pd.read_sql_query(q2,conn)
# Out:
#    MAX(population)
# 0       7256490011

# %%
pd.read_sql_query(q3,conn)
# Out:
#    MIN(population_growth)
# 0                     0.0

# %%
pd.read_sql_query(q4,conn)
# Out:
#    MAX(population_growth)
# 0                    4.02

# %%
q5 = "SELECT name FROM facts WHERE population = 0;"
pd.read_sql_query(q5,conn)
# Out:
#          name
# 0  Antarctica

# %%
q6 = "SELECT name FROM facts WHERE population = 7256490011"
pd.read_sql_query(q6,conn)

# %%
# wow, so many people in the world

# %%
q7 = "SELECT population, population_growth, birth_rate, death_rate FROM facts WHERE ((name != 'World')AND(name != 'Antarctica'));"
a = pd.read_sql_query(q7,conn)
a
# Out:
#       population  population_growth  birth_rate  death_rate
# 0     32564342.0               2.32       38.57       13.89
# 1      3029278.0               0.30       12.92        6.58
# 2     39542166.0               1.84       23.67        4.31
# 3        85580.0               0.12        8.13        6.96
# 4     19625353.0               2.78       38.78       11.49
# 5        92436.0               1.24       15.85        5.69
# 6     43431886.0               0.93       16.64        7.33
# 7      3056382.0               0.15       13.61        9.34
# 8     22751014.0               1.07       12.15        7.14
# 9      8665550.0               0.55        9.41        9.42
# 10     9780780.0               0.96       16.64        7.07
# 11      324597.0               0.85       15.50        7.05
# 12     1346613.0               2.41       13.66        2.69
# 13   168957745.0               1.60       21.14        5.61
# 14      290604.0               0.31       11.87        8.44
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.kdeplot(a['population'])
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/statsmodels/nonparametric/kde.py:454: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
# /dataquest/system/env/python3/lib/python3.4/site-packages/statsmodels/nonparametric/kde.py:454: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
